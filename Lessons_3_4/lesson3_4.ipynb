# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import joblib

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# #####  Создаем DF

# %%
columns=['id',
 'region',
 'objElemLivingCnt',
 'objElemParkingCnt',
 'objSquareLiving',
 'objLkClassDesc',
 'residentialBuildings',
 'objFloorCnt',
 'objFlatCnt',
 'objFlatSq',
 'objPriceAvg',
 'objReady100PercDt']

# %%
df=pd.read_pickle('build.pkl')[columns].drop_duplicates('id')
df['year']=pd.to_datetime(df['objReady100PercDt']).dt.year.astype('str')
live_class = df[df['objLkClassDesc'] != 'Другое']['objLkClassDesc'].unique() 
region = df['region'].unique()

# %% [markdown]
# ##### отбираем все классы жилья и регион, и в дальнейшем заменяем Nan цены на медиану по каждому классу объекта

# %%
for cla in live_class:
    for reg in region:
        filter = (df['objLkClassDesc'] == cla) & (df['region'] == reg)
        df.loc[filter,'med_price'] = df.loc[filter,'objPriceAvg'].fillna(df.loc[filter,'objPriceAvg'].median())
        df.loc[filter,'avg_price'] = df.loc[filter,'objPriceAvg'].fillna(df.loc[filter,'objPriceAvg'].mean())
        

df.loc[df['med_price'].isnull(),'med_price'] = df.med_price.median()
df.loc[df['avg_price'].isnull(),'avg_price'] = df.avg_price.median()

df['med_price'] = df['med_price'].astype(int)
df['avg_price'] = df['avg_price'].astype(int)

# %% [markdown]
# Определяем выборку регионов

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 9,12
df_grouped=df.groupby(['region'])['id'].count().reset_index().set_index(['region'])
df_grouped = df_grouped.rename(columns={'id': 'count_'})
df_grouped[df_grouped.count_ > 100].sort_values('count_',ascending = False).plot(kind='bar',stacked=True,figsize=(10,10))
# Out:
# <Axes: xlabel='region'>

# %% [markdown]
# Возьмем первые топ 5 регионов

# %%
top_reg=df.groupby(['region']).count().sort_values('id',ascending=False).reset_index().head(5)['region']

# %%
top_reg=df.groupby(['region']).count().sort_values('id',ascending=False).reset_index().head(5)['region']
df=df[df['region'].isin(top_reg)].reset_index(drop=True)
df.head()
# Out:
#       id  region  objElemLivingCnt  objElemParkingCnt  objSquareLiving  \
# 0  56006      54                24                  0          1003.20
# 1  18709      50               272                 30         12093.84
# 2  18708      50               272                  0         12057.80
# 3  27803      54                12                  0           889.20
# 4  23862      54                 6                  0           787.20
#
#   objLkClassDesc  residentialBuildings  objFloorCnt  objFlatCnt objFlatSq  \
# 0        Комфорт                     1            4          24    1003.2
# 1        Комфорт                     1           18         272  12093.84
# 2        Комфорт                     1           17         272   12057.8
# 3        Типовой                     1            3          12     889.2
# 4        Типовой                     1            3           6     787.2
#
#    objPriceAvg objReady100PercDt  year  med_price  avg_price
# 0          NaN        2024-12-31  2024     116964     123119
# 1      95270.0        2023-12-31  2023      95270      95270
# 2     100727.0        2023-12-31  2023     100727     100727
# 3          NaN        2024-03-31  2024      77721      77696
# 4          NaN        2024-03-31  2024      77721      77696

# %% [markdown]
# график этажей,парковок,колв-во квартир

# %%
target=['objElemParkingCnt','objFloorCnt','objFlatCnt']

sns.relplot(
    x='year',
    y='objFlatCnt',
    # hue='objLkClassDesc',
    data=df.groupby(['region','objLkClassDesc','year'])['objFlatCnt'].mean().reset_index(),
    row='region',
    kind='line',
    aspect=2,
    height=5)
# Out:
# d:\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# В основном, ко-во этажей из года в год будет увеличиваться.

# %%
sns.relplot(
    x='year',
    y='objFlatCnt',
    hue='objLkClassDesc',
    data=df.groupby(['region','objLkClassDesc','year'])['objFlatCnt'].mean().reset_index(),
    row='region',
    kind='line',
    aspect=2,
    height=5)
# Out:
# d:\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# в 23 регионе элитные дома строят на уровне первого этажа
#
# в 50 растет кол-во бизнес кварталов, тогда как обычные дома идут на спад. Элитных домов не наблюдается
#
# в 77 регионе идет спад на элитную\бизнес недвижимость, когда дома класса комфорт\типовые идут на подъем

# %%
target=['objElemParkingCnt','objFloorCnt','objFlatCnt']

sns.barplot(
    x='year',
    y='objElemParkingCnt',
    hue='region',
    data=df.groupby(['region','objLkClassDesc','year'])['objElemParkingCnt'].mean().reset_index())
# Out:
# <Axes: xlabel='year', ylabel='objElemParkingCnt'>

# %% [markdown]
# из го

# %% [markdown]
# График цен

# %%
df_prices = df[['region','objLkClassDesc','year','med_price','avg_price']]
df_price_long = pd.melt(df_prices,var_name='type',value_name='price',
                        id_vars=['region','objLkClassDesc','year'])
df_price_long
# Out:
#       region objLkClassDesc  year       type   price
# 0         54        Комфорт  2024  med_price  116964
# 1         50        Комфорт  2023  med_price   95270
# 2         50        Комфорт  2023  med_price  100727
# 3         54        Типовой  2024  med_price   77721
# 4         54        Типовой  2024  med_price   77721
# ...      ...            ...   ...        ...     ...
# 7755      50        Типовой  2024  avg_price   85604
# 7756      50        Типовой  2025  avg_price  181766
# 7757      50        Типовой  2024  avg_price   85610
# 7758      50        Типовой  2024  avg_price   85634
# 7759      50        Типовой  2027  avg_price   85515
#
# [7760 rows x 5 columns]

# %%
df_price_long.groupby(['region','objLkClassDesc','year','type'])['price'].mean().reset_index()
# Out:
#      region objLkClassDesc  year       type          price
# 0        23         Бизнес  2023  avg_price   88812.000000
# 1        23         Бизнес  2023  med_price   88812.000000
# 2        23         Бизнес  2024  avg_price  270777.319149
# 3        23         Бизнес  2024  med_price  261306.127660
# 4        23         Бизнес  2025  avg_price  354973.250000
# ..      ...            ...   ...        ...            ...
# 229      78        Элитный  2025  med_price  357197.000000
# 230      78        Элитный  2026  avg_price  373728.333333
# 231      78        Элитный  2026  med_price  373728.333333
# 232      78        Элитный  2027  avg_price  372993.000000
# 233      78        Элитный  2027  med_price  330432.000000
#
# [234 rows x 5 columns]

# %%
sns.relplot(
    x='year',
    y='price',
    hue='objLkClassDesc',
    data=df_price_long.groupby(['region','objLkClassDesc','year','type'])['price'].mean().reset_index(),
    row='region',
    kind='line',
    col='type',
    aspect=4,
    height=2)
# Out:
# d:\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# в 23 регионе цены на элитное жилье имеют сильное колебание от года к году, тогда как в других регионах,цены более стабильные.
# в 77 регионе сильнее всего растет элитное жилье

# %% [markdown]
# Посмотрим среднее значение цены по регионам за период по нескольим метрикам

# %%
df_long = pd.melt(df,var_name='type',value_name='znach',
                  id_vars=['id','region','objLkClassDesc','residentialBuildings','objPriceAvg','objReady100PercDt','year'])
# Out:
#           id  region objLkClassDesc  residentialBuildings  objPriceAvg  \
# 0      56006      54        Комфорт                     1          NaN
# 1      18709      50        Комфорт                     1      95270.0
# 2      18708      50        Комфорт                     1     100727.0
# 3      27803      54        Типовой                     1          NaN
# 4      23862      54        Типовой                     1          NaN
# ...      ...     ...            ...                   ...          ...
# 31035  28071      50        Типовой                     1      85604.0
# 31036  28070      50        Типовой                     1     181766.0
# 31037  28072      50        Типовой                     1      85610.0
# 31038  28073      50        Типовой                     1      85634.0
# 31039  28074      50        Типовой                     1      85515.0
#
#       objReady100PercDt  year              type   znach
# 0            2024-12-31  2024  objElemLivingCnt      24
# 1            2023-12-31  2023  objElemLivingCnt     272
# 2            2023-12-31  2023  objElemLivingCnt     272
# 3            2024-03-31  2024  objElemLivingCnt      12
# 4            2024-03-31  2024  objElemLivingCnt       6
# ...                 ...   ...               ...     ...
# 31035        2024-06-30  2024         avg_price   85604
# 31036        2025-03-31  2025         avg_price  181766
# 31037        2024-06-30  2024         avg_price   85610
# 31038        2024-06-30  2024         avg_price   85634
# 31039        2027-06-30  2027         avg_price   85515
#
# [31040 rows x 9 columns]

# %%
df
# Out:
#          id  region  objElemLivingCnt  objElemParkingCnt  objSquareLiving  \
# 0     56006      54                24                  0          1003.20
# 1     18709      50               272                 30         12093.84
# 2     18708      50               272                  0         12057.80
# 3     27803      54                12                  0           889.20
# 4     23862      54                 6                  0           787.20
# ...     ...     ...               ...                ...              ...
# 3875  28071      50               288                  0         14870.40
# 3876  28070      50               768                  0         29620.10
# 3877  28072      50               312                  0         14788.80
# 3878  28073      50               312                  0         14872.80
# 3879  28074      50               600                  0         29743.20
#
#      objLkClassDesc  residentialBuildings  objFloorCnt  objFlatCnt objFlatSq  \
# 0           Комфорт                     1            4          24    1003.2
# 1           Комфорт                     1           18         272  12093.84
# 2           Комфорт                     1           17         272   12057.8
# 3           Типовой                     1            3          12     889.2
# 4           Типовой                     1            3           6     787.2
# ...             ...                   ...          ...         ...       ...
# 3875        Типовой                     1           26         288   14870.4
# 3876        Типовой                     1           26         768   29620.1
# 3877        Типовой                     1           26         312   14788.8
# 3878        Типовой                     1           26         312   14872.8
# 3879        Типовой                     1           26         600   29743.2
#
#       objPriceAvg objReady100PercDt  year  med_price  avg_price
# 0             NaN        2024-12-31  2024     116964     123119
# 1         95270.0        2023-12-31  2023      95270      95270
# 2        100727.0        2023-12-31  2023     100727     100727
# 3             NaN        2024-03-31  2024      77721      77696
# 4             NaN        2024-03-31  2024      77721      77696
# ...           ...               ...   ...        ...        ...
# 3875      85604.0        2024-06-30  2024      85604      85604
# 3876     181766.0        2025-03-31  2025     181766     181766
# 3877      85610.0        2024-06-30  2024      85610      85610
# 3878      85634.0        2024-06-30  2024      85634      85634
# 3879      85515.0        2027-06-30  2027      85515      85515
#
# [3880 rows x 15 columns]

# %%
sns.relplot(
    x='year',
    y='znach',
    hue='type',
    data=df_long,
    kind='line')
# Out:
# d:\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
top_reg=df.groupby(['region']).count().sort_values('id',ascending=False).reset_index().head(5)['region']
test=df.copy()
test=df[df['region'].isin(top_reg)].reset_index(drop=True)

# %%
test.groupby(['region','objLkClassDesc','residentialBuildings','date'])['objElemLivingCnt'].mean().reset_index()
# Out:
#      region objLkClassDesc  residentialBuildings       date  objElemLivingCnt
# 0        23         Бизнес                     0 2024-03-31               0.0
# 1        23         Бизнес                     0 2024-06-30               0.0
# 2        23         Бизнес                     0 2024-09-30               0.0
# 3        23         Бизнес                     0 2024-12-31               0.0
# 4        23         Бизнес                     0 2025-03-31               0.0
# ..      ...            ...                   ...        ...               ...
# 455      78        Элитный                     1 2024-12-31             200.5
# 456      78        Элитный                     1 2025-06-30              68.0
# 457      78        Элитный                     1 2025-12-31              88.0
# 458      78        Элитный                     1 2026-09-30             717.0
# 459      78        Элитный                     1 2027-06-30             559.0
#
# [460 rows x 5 columns]

# %%
sns.violinplot(
    x='region',
    y='med_price',
    data=test,
    hue='objLkClassDesc'
    # kind='scatter'
#     kind='line'
)
plt.title('Диаграмма рассеяния', size=20, color='g');

# %%
d=test.groupby(['region','year'])['avg_price'].mean().reset_index()

# %%
d.pivot(index='year',columns='region',values='avg_price').plot(kind='bar')
# Out:
# <Axes: xlabel='year'>

# %%
test['year'] = test['date'].dt.year

# %%
d.pivot(index='year',columns='region',values='avg_price')
# Out:
# region             23             50             54            77  \
# year
# 2018              NaN  111650.000000            NaN           NaN
# 2020              NaN  100125.500000   77696.000000           NaN
# 2021     34367.000000            NaN            NaN  3.488980e+05
# 2022     25072.000000  169746.000000            NaN           NaN
# 2023    103281.293333  131338.466667   99184.468750  2.765664e+05
# 2024    170891.332203  142812.778107   94154.928030  3.470315e+05
# 2025    164232.777202  160417.731707  120022.125000  3.709463e+05
# 2026    151792.995968  175971.869565  109068.627907  5.057283e+05
# 2027    174118.062500  150346.750000  113270.250000  5.106836e+05
# 2028    176023.705882            NaN  169118.666667  1.124693e+06
# 2029     42225.333333            NaN  123119.000000           NaN
# 2030     38481.500000            NaN  123119.000000           NaN
# 2031     49470.000000            NaN            NaN           NaN
# 2032              NaN            NaN            NaN           NaN
#
# region             78
# year
# 2018              NaN
# 2020              NaN
# 2021              NaN
# 2022    171373.000000
# 2023    182476.313433
# 2024    190397.920561
# 2025    210015.475138
# 2026    196848.213333
# 2027    201770.769231
# 2028    125221.666667
# 2029    182518.000000
# 2030    182518.000000
# 2031    171373.000000
# 2032     30000.000000

# %%
test.groupby(['date','region','objLkClassDesc'])['med_price'].mean()
# Out:
# date        region  objLkClassDesc
# 2018-12-31  50      Другое            111736.0
# 2020-03-31  54      Типовой            77721.0
# 2020-09-30  50      Комфорт           137783.0
# 2020-12-31  50      Типовой            59988.0
# 2021-09-30  23      Комфорт            34367.0
#                                         ...
# 2031-06-30  23      Комфорт            49033.0
# 2031-09-30  23      Комфорт            49649.0
# 2031-12-31  23      Комфорт            49728.0
#             78      Типовой           177900.0
# 2032-12-31  78      Комфорт            30000.0
# Name: med_price, Length: 308, dtype: float64

# %%
df
# Out:
#   Категория  Значение
# 0         А         1
# 1         А         2
# 2         Б         3
# 3         Б         4
# 4         В         5
# 5         В         6

# %%
df = pd.DataFrame({
    'Категория': ['А', 'А', 'Б', 'Б', 'В', 'В'],
    'Значение': [1, 2, 3, 4, 5, 6]
})

# Используем метод pivot
result = df.pivot(index='Категория', columns='Значение', values='Значение')

print(result)
# Out:
# Значение     1    2    3    4    5    6
# Категория
# А          1.0  2.0  NaN  NaN  NaN  NaN
# Б          NaN  NaN  3.0  4.0  NaN  NaN
# В          NaN  NaN  NaN  NaN  5.0  6.0

# %%
graph_titles = ['График 1', 'График 2', 'График 3', 'График 4']

for i, title in enumerate(graph_titles):
    sns.relplot(
        x='date',
        y='med_price',
        data=test,
        hue='objLkClassDesc',
        col='region',
        col_wrap=5,
        col_order=top_reg,
        style='residentialBuildings',
        size='med_price',
        kind='line',
        label=title
    )

plt.title('Сравнение цен по региону и классу жилья по годам', size=20, color='g')

# Функция для форматирования оси y
def format_tick(value, pos):
    return f'{value}'

# Форматирование оси y с помощью функции matplotlib.ticker.FuncFormatter
formatter = mtick.FuncFormatter(format_tick)
plt.gca().yaxis.set_major_formatter(formatter)

# Добавьте сетку для основной оси y
plt.gca().yaxis.grid(True)

# Добавьте сетку для основной оси x
plt.gca().xaxis.grid(True)

# Добавьте второстепенную ось y и сетку
plt.gca().twinx()

# Установите межинтервальные значения для основных осей y и x
plt.gca().yaxis.set_major_locator(mtick.MaxNLocator(nbins=5))
plt.gca().xaxis.set_major_locator(mtick.MaxNLocator(nbins=5))

# Установите межинтервальные значения для второстепенной оси y
plt.gca().secondary_yaxis().set_major_locator(mtick.MaxNLocator(nbins=5))

plt.show()
# Out:
# d:\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# d:\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# d:\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\anaconda\Lib\site-packages\seaborn\_oldcore.py:1075, in VectorPlotter.iter_data(self, grouping_vars, reverse, from_comp_data, by_facet, allow_empty, dropna)
#    1074 try:
# -> 1075     data_subset = grouped_data.get_group(pd_key)
#    1076 except KeyError:
#    1077     # XXX we are adding this to allow backwards compatibility
#    1078     # with the empty artists that old categorical plots would
#    1079     # add (before 0.12), which we may decide to break, in which
#    1080     # case this option could be removed
#
# File d:\anaconda\Lib\site-packages\pandas\core\groupby\groupby.py:800, in BaseGroupBy.get_group(self, name, obj)
#     799 if not len(inds):
# --> 800     raise KeyError(name)
#     802 return obj._take_with_is_copy(inds, axis=self.axis)
#
# KeyError: ('Типовой', 282679, 1)
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[347], line 4
#       1 graph_titles = ['График 1', 'График 2', 'График 3', 'График 4']
#       3 for i, title in enumerate(graph_titles):
# ----> 4     sns.relplot(
#       5         x='date',
#       6         y='med_price',
#       7         data=test,
#       8         hue='objLkClassDesc',
#       9         col='region',
#      10         col_wrap=5,
#      11         col_order=top_reg,
#      12         style='residentialBuildings',
#      13         size='med_price',
#      14         kind='line',
#      15         label=title
#      16     )
#      18 plt.title('Сравнение цен по региону и классу жилья по годам', size=20, color='g')
#      20 # Функция для форматирования оси y
#
# File d:\anaconda\Lib\site-packages\seaborn\relational.py:955, in relplot(data, x, y, hue, size, style, units, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, **kwargs)
#     946 g = FacetGrid(
#     947     data=full_data.dropna(axis=1, how="all"),
#     948     **grid_kws,
#    (...)
#     951     **facet_kws
#     952 )
#     954 # Draw the plot
# --> 955 g.map_dataframe(func, **plot_kws)
#     957 # Label the axes, using the original variables
#     958 # Pass "" when the variable name is None to overwrite internal variables
#     959 g.set_axis_labels(variables.get("x") or "", variables.get("y") or "")
#
# File d:\anaconda\Lib\site-packages\seaborn\axisgrid.py:819, in FacetGrid.map_dataframe(self, func, *args, **kwargs)
#     816     kwargs["data"] = data_ijk
#     818     # Draw the plot
# --> 819     self._facet_plot(func, ax, args, kwargs)
#     821 # For axis labels, prefer to use positional args for backcompat
#     822 # but also extract the x/y kwargs and use if no corresponding arg
#     823 axis_labels = [kwargs.get("x", None), kwargs.get("y", None)]
#
# File d:\anaconda\Lib\site-packages\seaborn\axisgrid.py:848, in FacetGrid._facet_plot(self, func, ax, plot_args, plot_kwargs)
#     846     plot_args = []
#     847     plot_kwargs["ax"] = ax
# --> 848 func(*plot_args, **plot_kwargs)
#     850 # Sort out the supporting information
#     851 self._update_legend_data(ax)
#
# File d:\anaconda\Lib\site-packages\seaborn\relational.py:645, in lineplot(data, x, y, hue, size, style, units, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     642 color = kwargs.pop("color", kwargs.pop("c", None))
#     643 kwargs["color"] = _default_color(ax.plot, hue, color, kwargs)
# --> 645 p.plot(ax, kwargs)
#     646 return ax
#
# File d:\anaconda\Lib\site-packages\seaborn\relational.py:423, in _LinePlotter.plot(self, ax, kws)
#     415 # TODO How to handle NA? We don't want NA to propagate through to the
#     416 # estimate/CI when some values are present, but we would also like
#     417 # matplotlib to show "gaps" in the line when all values are missing.
#    (...)
#     420
#     421 # Loop over the semantic subsets and add to the plot
#     422 grouping_vars = "hue", "size", "style"
# --> 423 for sub_vars, sub_data in self.iter_data(grouping_vars, from_comp_data=True):
#     425     if self.sort:
#     426         sort_vars = ["units", orient, other]
#
# File d:\anaconda\Lib\site-packages\seaborn\_oldcore.py:1081, in VectorPlotter.iter_data(self, grouping_vars, reverse, from_comp_data, by_facet, allow_empty, dropna)
#    1075     data_subset = grouped_data.get_group(pd_key)
#    1076 except KeyError:
#    1077     # XXX we are adding this to allow backwards compatibility
#    1078     # with the empty artists that old categorical plots would
#    1079     # add (before 0.12), which we may decide to break, in which
#    1080     # case this option could be removed
# -> 1081     data_subset = data.loc[[]]
#    1083 if data_subset.empty and not allow_empty:
#    1084     continue
#
# File d:\anaconda\Lib\site-packages\pandas\core\indexing.py:1103, in _LocationIndexer.__getitem__(self, key)
#    1100 axis = self.axis or 0
#    1102 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1103 return self._getitem_axis(maybe_callable, axis=axis)
#
# File d:\anaconda\Lib\site-packages\pandas\core\indexing.py:1332, in _LocIndexer._getitem_axis(self, key, axis)
#    1329     if hasattr(key, "ndim") and key.ndim > 1:
#    1330         raise ValueError("Cannot index with multidimensional key")
# -> 1332     return self._getitem_iterable(key, axis=axis)
#    1334 # nested tuple slicing
#    1335 if is_nested_tuple(key, labels):
#
# File d:\anaconda\Lib\site-packages\pandas\core\indexing.py:1272, in _LocIndexer._getitem_iterable(self, key, axis)
#    1269 self._validate_key(key, axis)
#    1271 # A collection of keys
# -> 1272 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1273 return self.obj._reindex_with_indexers(
#    1274     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1275 )
#
# File d:\anaconda\Lib\site-packages\pandas\core\indexing.py:1462, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1459 ax = self.obj._get_axis(axis)
#    1460 axis_name = self.obj._get_axis_name(axis)
# -> 1462 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1464 return keyarr, indexer
#
# File d:\anaconda\Lib\site-packages\pandas\core\indexes\base.py:5879, in Index._get_indexer_strict(self, key, axis_name)
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5877 self._raise_if_missing(keyarr, indexer, axis_name)
# -> 5879 keyarr = self.take(indexer)
#    5880 if isinstance(key, Index):
#    5881     # GH 42790 - Preserve name from an Index
#    5882     keyarr.name = key.name
#
# File d:\anaconda\Lib\site-packages\pandas\core\indexes\base.py:1090, in Index.take(self, indices, axis, allow_fill, fill_value, **kwargs)
#    1088 values = self._values
#    1089 if isinstance(values, np.ndarray):
# -> 1090     taken = algos.take(
#    1091         values, indices, allow_fill=allow_fill, fill_value=self._na_value
#    1092     )
#    1093 else:
#    1094     # algos.take passes 'axis' keyword which not all EAs accept
#    1095     taken = values.take(
#    1096         indices, allow_fill=allow_fill, fill_value=self._na_value
#    1097     )
#
# File d:\anaconda\Lib\site-packages\pandas\core\algorithms.py:1258, in take(arr, indices, axis, allow_fill, fill_value)
#    1253     result = take_nd(
#    1254         arr, indices, axis=axis, allow_fill=True, fill_value=fill_value
#    1255     )
#    1256 else:
#    1257     # NumPy style
# -> 1258     result = arr.take(indices, axis=axis)
#    1259 return result
#
# KeyboardInterrupt:
